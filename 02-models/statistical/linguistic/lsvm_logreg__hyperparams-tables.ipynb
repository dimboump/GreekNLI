# %%
from IPython.display import display as ipy_display
import numpy as np
import pandas as pd
import matplotlib as mpl
from matplotlib import pyplot as plt

# %config InlineBackend.figure_format = 'svg'

# %%
best_models_df = pd.read_csv('best_models.csv', encoding='utf-8')
best_models_df.sample(5)
# Out:
#     model                          base  mean_test_score  rank_test_score  \
# 230   SGD  SGDClassifier(max_iter=5000)         0.578891            231.0
# 157   SGD  SGDClassifier(max_iter=5000)         0.668777            158.0
# 27    SGD  SGDClassifier(max_iter=5000)         0.761204             28.0
# 240   SGD  SGDClassifier(max_iter=5000)         0.576845            241.0
# 356   SGD  SGDClassifier(max_iter=5000)         0.332344            357.0
#
#      clf__alpha clf__loss clf__penalty  cxf__chars__min_df  \
# 230         NaN       NaN          NaN                 NaN
# 157       1.000     hinge           l1                0.25
# 27        0.100     hinge           l2                0.25
# 240       0.001  log_loss           l2                0.10
# 356       1.000     hinge           l2                0.10
#
#     cxf__postf__ngram_range cxf__words__ngram_range  clf__C
# 230                  (1, 1)                  (1, 2)    0.01
# 157                  (1, 2)                  (1, 3)     NaN
# 27                   (1, 3)                  (1, 3)     NaN
# 240                  (1, 3)                  (1, 1)     NaN
# 356                  (1, 1)                  (1, 3)     NaN

# %%
sgd = (
    best_models_df
       [(best_models_df['model'] == 'SGD') & (best_models_df['clf__loss'].notna())]
       .sort_values('mean_test_score', ascending=True)
       .reset_index(drop=True)
)
sgd
# Out:
#     model                          base  mean_test_score  rank_test_score  \
# 0     SGD  SGDClassifier(max_iter=5000)         0.332292            359.0
# 1     SGD  SGDClassifier(max_iter=5000)         0.332293            358.0
# 2     SGD  SGDClassifier(max_iter=5000)         0.332344            357.0
# 3     SGD  SGDClassifier(max_iter=5000)         0.332395            355.0
# 4     SGD  SGDClassifier(max_iter=5000)         0.332445            354.0
# ..    ...                           ...              ...              ...
# 292   SGD  SGDClassifier(max_iter=5000)         0.770176              5.0
# 293   SGD  SGDClassifier(max_iter=5000)         0.770615              4.0
# 294   SGD  SGDClassifier(max_iter=5000)         0.770894              3.0
# 295   SGD  SGDClassifier(max_iter=5000)         0.770950              2.0
# 296   SGD  SGDClassifier(max_iter=5000)         0.772847              1.0
#
#      clf__alpha clf__loss clf__penalty  cxf__chars__min_df  \
# 0        0.0100     hinge           l1                0.10
# 1        0.1000     hinge           l1                0.10
# 2        1.0000     hinge           l2                0.10
# 3        0.0100  log_loss           l2                0.25
# 4        1.0000     hinge           l1                0.25
# ..          ...       ...          ...                 ...
# 292      0.0100     hinge           l2                0.25
# 293      0.0001  log_loss           l2                0.25
# 294      0.0010  log_loss           l2                0.25
# 295      0.0100  log_loss           l2                0.10
# 296      0.0010     hinge           l1                0.10
#
#     cxf__postf__ngram_range cxf__words__ngram_range  clf__C
# 0                    (1, 2)                  (1, 2)     NaN
# 1                    (1, 2)                  (1, 2)     NaN
# 2                    (1, 1)                  (1, 3)     NaN
# 3                    (1, 1)                  (1, 2)     NaN
# 4                    (1, 1)                  (1, 2)     NaN
# ..                      ...                     ...     ...
# 292                  (1, 2)                  (1, 2)     NaN
# 293                  (1, 2)                  (1, 2)     NaN
# 294                  (1, 2)                  (1, 3)     NaN
# 295                  (1, 2)                  (1, 3)     NaN
# 296                  (1, 1)                  (1, 2)     NaN
#
# [297 rows x 11 columns]

# %%
sgd.columns
# Out:
# Index(['model', 'base', 'mean_test_score', 'rank_test_score', 'clf__alpha',
#        'clf__loss', 'clf__penalty', 'cxf__chars__min_df',
#        'cxf__postf__ngram_range', 'cxf__words__ngram_range', 'clf__C'],
#       dtype='object')

# %%
from ast import literal_eval

colors = ['#a52040', '#404080']
markers = ['o', 's']

params = [col for col in sgd.columns
          if col.startswith('cxf__') or col.startswith('clf__')
          and col not in ['clf__C',]]

ngram_cols = [col for col in params if col.endswith('__ngram_range')]
# convert ngram_range to float for better visualization
for col in ngram_cols:
    sgd[col] = sgd[col].apply(lambda x: literal_eval(f"{x[1:-1]}".replace(', ', '.')))

all_params = pd.DataFrame()

# which are the best hyperparameters for each loss function?
for loss in sgd['clf__loss'].unique():
    hyperparams_df = (
        pd.DataFrame(sgd[sgd['clf__loss'] == loss][params + ['mean_test_score']])
            .sort_values('mean_test_score', ascending=False)
            .reset_index(drop=True)
    )
    hyperparams_df.index += 1
    hyperparams_df.index.name = 'rank'
    hyperparams_df = hyperparams_df.rename(columns={'mean_test_score': 'F1_score'})
    model_name = 'lsvm' if loss == 'hinge' else 'logreg'
    ipy_display(
        hyperparams_df
            .style
            .format({
                'mean_test_score': '{:.3f}'.format, # format score
                'clf__alpha': '{:g}'.format, # format alpha, exponent notation
                'cxf__chars__min_df': '{:g}'.format, # format alpha, exponent notation
                'clf__penalty': lambda x: rf"$\ell_{{{x}}}$", # format penalty
                **{col: lambda x: ", ".join(f"{x}".split('.'))
                for col in ngram_cols}, # convert ngram_range back
            })
            .background_gradient(cmap='RdBu', axis=0)
            .set_caption(f'Best hyperparameters for {loss=}')
    )

    all_params = pd.concat([all_params, hyperparams_df])
# Out:
# <style type="text/css">
# #T_f2c8a_row0_col0, #T_f2c8a_row0_col3, #T_f2c8a_row0_col4, #T_f2c8a_row2_col3, #T_f2c8a_row2_col5, #T_f2c8a_row3_col3, #T_f2c8a_row3_col4, #T_f2c8a_row3_col5, #T_f2c8a_row4_col0, #T_f2c8a_row4_col3, #T_f2c8a_row4_col5, #T_f2c8a_row5_col0, #T_f2c8a_row6_col3, #T_f2c8a_row7_col0, #T_f2c8a_row7_col4, #T_f2c8a_row8_col0, #T_f2c8a_row8_col3, #T_f2c8a_row8_col4, #T_f2c8a_row11_col0, #T_f2c8a_row12_col5, #T_f2c8a_row13_col3, #T_f2c8a_row14_col3, #T_f2c8a_row14_col5, #T_f2c8a_row15_col4, #T_f2c8a_row17_col5, #T_f2c8a_row18_col3, #T_f2c8a_row18_col4, #T_f2c8a_row19_col3, #T_f2c8a_row21_col3, #T_f2c8a_row21_col4, #T_f2c8a_row22_col4, #T_f2c8a_row23_col4, #T_f2c8a_row24_col3, #T_f2c8a_row24_col4, #T_f2c8a_row24_col5, #T_f2c8a_row25_col3, #T_f2c8a_row25_col4, #T_f2c8a_row25_col5, #T_f2c8a_row26_col3, #T_f2c8a_row26_col4, #T_f2c8a_row26_col5, #T_f2c8a_row27_col3, #T_f2c8a_row28_col3, #T_f2c8a_row29_col3, #T_f2c8a_row29_col5, #T_f2c8a_row30_col3, #T_f2c8a_row30_col5, #T_f2c8a_row31_col4, #T_f2c8a_row31_col5, #T_f2c8a_row32_col4, #T_f2c8a_row32_col5, #T_f2c8a_row33_col0, #T_f2c8a_row33_col4, #T_f2c8a_row34_col3, #T_f2c8a_row34_col4, #T_f2c8a_row36_col0, #T_f2c8a_row37_col3, #T_f2c8a_row37_col4, #T_f2c8a_row39_col3, #T_f2c8a_row41_col3, #T_f2c8a_row43_col3, #T_f2c8a_row44_col0, #T_f2c8a_row44_col5, #T_f2c8a_row45_col3, #T_f2c8a_row46_col0, #T_f2c8a_row46_col3, #T_f2c8a_row47_col4, #T_f2c8a_row49_col3, #T_f2c8a_row49_col5, #T_f2c8a_row50_col0, #T_f2c8a_row51_col5, #T_f2c8a_row52_col3, #T_f2c8a_row53_col3, #T_f2c8a_row54_col3, #T_f2c8a_row55_col0, #T_f2c8a_row55_col4, #T_f2c8a_row55_col5, #T_f2c8a_row56_col0, #T_f2c8a_row56_col3, #T_f2c8a_row56_col4, #T_f2c8a_row57_col3, #T_f2c8a_row57_col5, #T_f2c8a_row60_col3, #T_f2c8a_row60_col5, #T_f2c8a_row61_col0, #T_f2c8a_row61_col3, #T_f2c8a_row61_col4, #T_f2c8a_row61_col5, #T_f2c8a_row62_col0, #T_f2c8a_row62_col3, #T_f2c8a_row63_col0, #T_f2c8a_row63_col3, #T_f2c8a_row64_col0, #T_f2c8a_row65_col3, #T_f2c8a_row65_col4, #T_f2c8a_row67_col3, #T_f2c8a_row68_col5, #T_f2c8a_row69_col4, #T_f2c8a_row70_col4, #T_f2c8a_row71_col3, #T_f2c8a_row73_col4, #T_f2c8a_row74_col3, #T_f2c8a_row74_col5, #T_f2c8a_row75_col0, #T_f2c8a_row75_col4, #T_f2c8a_row76_col0, #T_f2c8a_row76_col3, #T_f2c8a_row77_col0, #T_f2c8a_row77_col3, #T_f2c8a_row81_col3, #T_f2c8a_row81_col4, #T_f2c8a_row82_col4, #T_f2c8a_row83_col3, #T_f2c8a_row83_col4, #T_f2c8a_row84_col5, #T_f2c8a_row86_col0, #T_f2c8a_row86_col3, #T_f2c8a_row87_col4, #T_f2c8a_row87_col5, #T_f2c8a_row89_col4, #T_f2c8a_row90_col3, #T_f2c8a_row91_col5, #T_f2c8a_row92_col3, #T_f2c8a_row93_col3, #T_f2c8a_row93_col5, #T_f2c8a_row94_col0, #T_f2c8a_row94_col5, #T_f2c8a_row95_col0, #T_f2c8a_row95_col3, #T_f2c8a_row95_col5, #T_f2c8a_row96_col3, #T_f2c8a_row96_col4, #T_f2c8a_row96_col5, #T_f2c8a_row97_col4, #T_f2c8a_row97_col5, #T_f2c8a_row98_col3, #T_f2c8a_row99_col4, #T_f2c8a_row99_col5, #T_f2c8a_row100_col3, #T_f2c8a_row100_col4, #T_f2c8a_row101_col0, #T_f2c8a_row102_col0, #T_f2
5, #T_f2c8a_row88_col4, #T_f2c8a_row89_col5, #T_f2c8a_row90_col4, #T_f2c8a_row90_col5, #T_f2c8a_row91_col4, #T_f2c8a_row92_col4, #T_f2c8a_row94_col4, #T_f2c8a_row103_col4, #T_f2c8a_row105_col5, #T_f2c8a_row110_col4, #T_f2c8a_row111_col4, #T_f2c8a_row112_col4, #T_f2c8a_row113_col4, #T_f2c8a_row114_col4, #T_f2c8a_row115_col4, #T_f2c8a_row115_col5, #T_f2c8a_row116_col4, #T_f2c8a_row118_col4, #T_f2c8a_row119_col4, #T_f2c8a_row119_col5, #T_f2c8a_row121_col5, #T_f2c8a_row125_col4, #T_f2c8a_row126_col4, #T_f2c8a_row127_col5, #T_f2c8a_row128_col5, #T_f2c8a_row131_col4, #T_f2c8a_row131_col5, #T_f2c8a_row135_col5, #T_f2c8a_row136_col4, #T_f2c8a_row136_col5, #T_f2c8a_row137_col5, #T_f2c8a_row139_col4, #T_f2c8a_row139_col5, #T_f2c8a_row140_col4, #T_f2c8a_row140_col5 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_f2c8a_row0_col6, #T_f2c8a_row1_col3, #T_f2c8a_row5_col3, #T_f2c8a_row5_col5, #T_f2c8a_row6_col4, #T_f2c8a_row6_col5, #T_f2c8a_row7_col3, #T_f2c8a_row8_col5, #T_f2c8a_row9_col3, #T_f2c8a_row9_col4, #T_f2c8a_row9_col5, #T_f2c8a_row10_col3, #T_f2c8a_row10_col4, #T_f2c8a_row11_col3, #T_f2c8a_row11_col4, #T_f2c8a_row12_col0, #T_f2c8a_row12_col3, #T_f2c8a_row13_col4, #T_f2c8a_row14_col0, #T_f2c8a_row15_col3, #T_f2c8a_row15_col5, #T_f2c8a_row16_col3, #T_f2c8a_row16_col5, #T_f2c8a_row17_col3, #T_f2c8a_row17_col4, #T_f2c8a_row20_col3, #T_f2c8a_row20_col4, #T_f2c8a_row21_col0, #T_f2c8a_row22_col3, #T_f2c8a_row23_col3, #T_f2c8a_row24_col0, #T_f2c8a_row26_col0, #T_f2c8a_row27_col0, #T_f2c8a_row27_col5, #T_f2c8a_row28_col0, #T_f2c8a_row28_col4, #T_f2c8a_row30_col4, #T_f2c8a_row31_col3, #T_f2c8a_row32_col0, #T_f2c8a_row32_col3, #T_f2c8a_row33_col3, #T_f2c8a_row33_col5, #T_f2c8a_row34_col0, #T_f2c8a_row35_col3, #T_f2c8a_row35_col5, #T_f2c8a_row36_col3, #T_f2c8a_row37_col0, #T_f2c8a_row37_col5, #T_f2c8a_row38_col3, #T_f2c8a_row38_col4, #T_f2c8a_row40_col3, #T_f2c8a_row40_col5, #T_f2c8a_row41_col4, #T_f2c8a_row41_col5, #T_f2c8a_row42_col3, #T_f2c8a_row42_col4, #T_f2c8a_row42_col5, #T_f2c8a_row43_col0, #T_f2c8a_row43_col4, #T_f2c8a_row43_col5, #T_f2c8a_row44_col3, #T_f2c8a_row44_col4, #T_f2c8a_row45_col4, #T_f2c8a_row45_col5, #T_f2c8a_row46_col4, #T_f2c8a_row46_col5, #T_f2c8a_row47_col3, #T_f2c8a_row47_col5, #T_f2c8a_row48_col0, #T_f2c8a_row48_col3, #T_f2c8a_row48_col4, #T_f2c8a_row48_col5, #T_f2c8a_row49_col4, #T_f2c8a_row50_col3, #T_f2c8a_row50_col4, #T_f2c8a_row50_col5, #T_f2c8a_row51_col3, #T_f2c8
#           5          0.001     hinge           l1                0.10
# ...                    ...       ...          ...                 ...
# log_loss  152        1.000  log_loss           l1                0.10
#           153        0.010  log_loss           l1                0.10
#           154        1.000  log_loss           l2                0.10
#           155        0.001  log_loss           l2                0.10
#           156        0.010  log_loss           l2                0.25
#
#                 cxf__postf__ngram_range  cxf__words__ngram_range  F1_score
# clf__loss rank
# hinge     1                         1.1                      1.2  0.772847
#           2                         1.2                      1.2  0.770176
#           3                         1.2                      1.1  0.767881
#           4                         1.1                      1.1  0.767764
#           5                         1.2                      1.1  0.764003
# ...                                 ...                      ...       ...
# log_loss  152                       1.3                      1.3  0.333327
#           153                       1.3                      1.2  0.333276
#           154                       1.1                      1.1  0.333276
#           155                       1.1                      1.3  0.333276
#           156                       1.1                      1.2  0.332395
#
# [297 rows x 7 columns]

# %%
all_params = all_params.drop(columns=['clf__loss'])
all_params
# Out:
#                 clf__alpha clf__penalty  cxf__chars__min_df  \
# clf__loss rank
# hinge     1          0.001           l1                0.10
#           2          0.010           l2                0.25
#           3          0.010           l2                0.10
#           4          0.010           l1                0.10
#           5          0.001           l1                0.10
# ...                    ...          ...                 ...
# log_loss  152        1.000           l1                0.10
#           153        0.010           l1                0.10
#           154        1.000           l2                0.10
#           155        0.001           l2                0.10
#           156        0.010           l2                0.25
#
#                 cxf__postf__ngram_range  cxf__words__ngram_range  F1_score
# clf__loss rank
# hinge     1                         1.1                      1.2  0.772847
#           2                         1.2                      1.2  0.770176
#           3                         1.2                      1.1  0.767881
#           4                         1.1                      1.1  0.767764
#           5                         1.2                      1.1  0.764003
# ...                                 ...                      ...       ...
# log_loss  152                       1.3                      1.3  0.333327
#           153                       1.3                      1.2  0.333276
#           154                       1.1                      1.1  0.333276
#           155                       1.1                      1.3  0.333276
#           156                       1.1                      1.2  0.332395
#
# [297 rows x 6 columns]

# %%
all_params['clf__alpha'] = all_params['clf__alpha'].apply("{:g}".format)

# %%
for col in ngram_cols:
    all_params[col] = (
        all_params[col]
         .astype(str)
         .apply(lambda x: 
                        "$n = " + "-".join(x.split('.'))
                        .removeprefix('[')
                        .removesuffix(']') + "$")
                        .astype(str)
    )

all_params = (
    all_params
   .rename(columns={
        col: col.removeprefix('clf__').removeprefix('cxf__')
        for col in all_params.columns
   })
)
all_params['F1_score'] = all_params['F1_score'].round(3)
all_params = all_params.rename_axis(index={'clf__loss': 'loss'})
best_params = all_params.groupby('loss').head(10)
best_params
# Out:
#                 alpha penalty  chars__min_df postf__ngram_range  \
# loss     rank
# hinge    1      0.001      l1           0.10          $n = 1-1$
#          2       0.01      l2           0.25          $n = 1-2$
#          3       0.01      l2           0.10          $n = 1-2$
#          4       0.01      l1           0.10          $n = 1-1$
#          5      0.001      l1           0.10          $n = 1-2$
#          6     0.0001      l1           0.25          $n = 1-2$
#          7        0.1      l2           0.10          $n = 1-3$
#          8      0.001      l1           0.25          $n = 1-1$
#          9     0.0001      l1           0.10          $n = 1-1$
#          10       0.1      l2           0.25          $n = 1-3$
# log_loss 1       0.01      l2           0.10          $n = 1-2$
#          2      0.001      l2           0.25          $n = 1-2$
#          3     0.0001      l2           0.25          $n = 1-2$
#          4        0.1      l1           0.10          $n = 1-2$
#          5        0.1      l1           0.10          $n = 1-1$
#          6          1      l2           0.25          $n = 1-1$
#          7        0.1      l2           0.25          $n = 1-2$
#          8      0.001      l2           0.10          $n = 1-2$
#          9      0.001      l1           0.25          $n = 1-3$
#          10    0.0001      l2           0.25          $n = 1-2$
#
#               words__ngram_range  F1_score
# loss     rank
# hinge    1             $n = 1-2$     0.773
#          2             $n = 1-2$     0.770
#          3             $n = 1-1$     0.768
#          4             $n = 1-1$     0.768
#          5             $n = 1-1$     0.764
#          6             $n = 1-3$     0.763
#          7             $n = 1-3$     0.763
#          8             $n = 1-2$     0.762
#          9             $n = 1-3$     0.762
#          10            $n = 1-3$     0.761
# log_loss 1             $n = 1-3$     0.771
#          2             $n = 1-3$     0.771
#          3             $n = 1-2$     0.771
#          4             $n = 1-3$     0.769
#          5             $n = 1-2$     0.767
#          6             $n = 1-1$     0.765
#          7             $n = 1-1$     0.765
#          8             $n = 1-2$     0.764
#          9             $n = 1-2$     0.764
#          10            $n = 1-1$     0.763

# %%
best_params.style.to_latex('best_hyperparams_sgdclassifier.tex', 
                            position='h!', position_float='centering', hrules=True, 
                            multicol_align='c', multirow_align='t', encoding='utf-8',
                            caption="Top 10 best hyperparameters for the two linear classifiers.")

# %%
import plotly.express as px


def shorten_param(param_name: str) -> str:
    """Remove components' prefixes in param_name."""
    if "__" in param_name:
        return param_name.split("__", 1)[1]
    return param_name


plot_results_df = best_models_df.copy().drop(columns=['model', 'base', 'rank_test_score', 'clf__C'])
plot_results_df = plot_results_df.rename(shorten_param, axis=1)
plot_results_df = plot_results_df.rename(columns={
                                            'mean_test_score': 'F1-macro',
                                            'chars__min_df': 'min_df',
                                            'postf__ngram_range': 'POS n-grams',
                                            'words__ngram_range': 'Word n-grams',
                                        })

column_results = [shorten_param(col) for col in plot_results_df.columns]
column_results = column_results[1:] + column_results[:1]

# Create a dictionary of functions to transform the values of the columns
transform_funcs = dict.fromkeys(column_results, lambda x: x)
transform_funcs['min_df'] = lambda x: x
transform_funcs['F1-macro'] = lambda x: round(x, 2)
# Using a logarithmic scale for alpha
transform_funcs['alpha'] = lambda x: x
# L1 norms are mapped to index 1, and L2 norms to index 2
transform_funcs['loss'] = lambda x: 2 if x == "hinge" else 1
# L1 norms are mapped to index 1, and L2 norms to index 2
transform_funcs['penalty'] = lambda x: 2 if x == "l2" else 1
# Unigrams are mapped to index 1 and bigrams to index 2
transform_funcs['POS n-grams'] = lambda x: x[0]
# Unigrams are mapped to index 1 and bigrams to index 2
transform_funcs['Word n-grams'] = lambda x: x[1]


fig = px.parallel_coordinates(
    plot_results_df[column_results].apply(transform_funcs),
    color='F1-macro',
    color_continuous_scale=px.colors.sequential.RdBu,
)
fig.update_layout(
    title={
        'text': "Best hyperparameters (LSVM vs LogReg)",
        'y': 0.99,
        'x': 0.5,
        'xanchor': 'center',
        'yanchor': 'top',
    }
)
fig.show(renderer='svg')
# Out:
# c:\Users\dimboump\workspace\GreekNLI\venv\lib\site-packages\plotly\express\_core.py:279: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   dims = [
